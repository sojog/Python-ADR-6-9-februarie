# %%
'I'm taking the python exam'
# Out:
#   Cell In[2], line 1
#     'I'm taking the python exam'
#                                ^
# SyntaxError: unterminated string literal (detected at line 1)

# %%
"I'm taking the python exam"
# Out:
# "I'm taking the python exam"

# %%
'I\'m taking the python exam'
# Out:
# "I'm taking the python exam"

# %%
print('I\'m taking the python exam')
# Out:
# I'm taking the python exam

# %%
""" ??? """
# Out:
# ' ??? '

# %%
class Persoana:
    """
    Docstring for Persoana - ***
    """

# %%
help(Persoana)
# Out:
# Help on class Persoana in module __main__:
#
# class Persoana(builtins.object)
#  |  Docstring for Persoana - ***
#  |
#  |  Data descriptors defined here:
#  |
#  |  __dict__
#  |      dictionary for instance variables
#  |
#  |  __weakref__
#  |      list of weak references to the object

# %%
Persoana.__doc__
# Out:
# '\nDocstring for Persoana - ***\n'

# %%
print('I\'\n')
# Out:
# I'

# %%
1st_var = 'hello'
print(1st_var)
# Out:
#   Cell In[13], line 1
#     1st_var = 'hello'
#     ^
# SyntaxError: invalid decimal literal

# %%
from = 'hello'
print(from)
# Out:
#   Cell In[14], line 1
#     from = 'hello'
#          ^
# SyntaxError: invalid syntax

# %%
greeting = 'hello'
print(Greeting)
Greeting = 'How are you'
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 2
#       1 greeting = 'hello'
# ----> 2 print(Greeting)
#       3 Greeting = 'How are you'
#
# NameError: name 'Greeting' is not defined

# %%
has_greeted = true
print(has_greeted)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 has_greeted = true
#       2 print(has_greeted)
#
# NameError: name 'true' is not defined

# %%
has_greeted = True
print(has_greeted)
# Out:
# True

# %%
has_greeted = 'true'
print(has_greeted)
# Out:
# true

# %%
true = 0
has_greeted = true
print(has_greeted)
# Out:
# 0

# %%
a = 100_200_300
print(a, type(a))
# Out:
# 100200300 <class 'int'>

# %%
a = 100200300
print(a, type(a))
# Out:
# 100200300 <class 'int'>

# %%
a = 1_200_300_400
print(a, type(a))
# Out:
# 1200300400 <class 'int'>

# %%
a = 5E10
print(a)
# Out:
# 50000000000.0

# %%
a = 5 * 10 ** 10
print(a)
# Out:
# 50000000000

# %%
number = 1234567890
f"{number:,.2f}"
# Out:
# '1,234,567,890.00'

# %%
number = 1234567890
f"{number:,}"
# Out:
# '1,234,567,890'

# %%
a = 8E-5
print(a, type(a))
# Out:
# 8e-05 <class 'float'>

# %%
print(a)
# Out:
# 8e-05

# %%
print(str(a))
# Out:
# 8e-05

# %%
f"{a:,.5f}"
# Out:
# '0.00008'

# %%
a = 8 * 10 ** (-4)
a
# Out:
# 0.0008

# %%
a = 0X20
print (a)
# Out:
# 32

# %%
a = 0XFF
print (a)
# Out:
# 255

# %%
# baza 16: 0...15  A-10, B-11, C-12, D-13, E-14, F-15

# %%
a = 0XFFFFFF # 255 (R) 255 (G) 255 (B)
print (a)
# Out:
# 16777215

# %%
# hello = "kjdk"
print (hello)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[49], line 2
#       1 # hello = "kjdk"
# ----> 2 print (hello)
#
# NameError: name 'hello' is not defined

# %%
print (9//2)
# Out:
# 4

# %%
print (9/2)
# Out:
# 4.5

# %%
print (int(11/2))
# Out:
# 5

# %%
print(int(4.9))
# Out:
# 4

# %%
11 % 2
# Out:
# 1

# %%
print (9*"2")
# Out:
# 222222222

# %%
print ("2"+"2")
# Out:
# 22

# %%
print ("2"*9.1)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 print ("2"*9.0)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
print ("2"*"9")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[58], line 1
# ----> 1 print ("2"*"9")
#
# TypeError: can't multiply sequence by non-int of type 'str'

# %%
print (9+"2")
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[59], line 1
# ----> 1 print (9+"2")
#
# TypeError: unsupported operand type(s) for +: 'int' and 'str'

# %%
print (9**2)
# Out:
# 81

# %%
print (2*1**2)
# Out:
# 2

# %%
print ('a'+'b'*2+4*'a' )
# Out:
# abbaaaa

# %%
x = 2**2**3
print (x)
# Out:
# 256

# %%
a = 2
b = 3

# %%
aux = a
a = b
b = aux
print("a=", a)
print("b=", b)
# Out:
# a= 3
# b= 2

# %%
a, b
# Out:
# (3, 2)

# %%
a, b = b, a

# %%
# packing
x = (66, 88)
x
# Out:
# (66, 88)

# %%
# unpacking
m, n = x
print("m=", m)
print("n = ", n)
# Out:
# m= 66
# n =  88

# %%
q, w = (100, 200, 300)

print("q=", q)
print("w=", w)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[71], line 1
# ----> 1 q, w = (100, 200, 300)
#       3 print("q=", q)
#       4 print("w=", w)
#
# ValueError: too many values to unpack (expected 2, got 3)

# %%
q, w, e, r = (100, 200, 300)

print("q=", q)
print("w=", w)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[72], line 1
# ----> 1 q, w, e, r = (100, 200, 300)
#       3 print("q=", q)
#       4 print("w=", w)
#
# ValueError: not enough values to unpack (expected 4, got 3)

# %%
q, w, _ = (100, 200, 300)

print("q=", q)
print("w=", w)
print("_", _)
# Out:
# q= 100
# w= 200
# _ 300

# %%
_ + 320
# Out:
# 620

# %%
q, *w = (100, 200, 300)

print("q=", q)
print("w=", w)
# Out:
# q= 100
# w= [200, 300]

# %%
q, *w = (100, 200, 300, 400, 500, 600)

print("q=", q)
print("w=", w)
# Out:
# q= 100
# w= [200, 300, 400, 500, 600]

# %%
q, *w, r = (100, 200, 300, 400, 500, 600)

print("q=", q)
print("w=", w)
print("r=", r)
# Out:
# q= 100
# w= [200, 300, 400, 500]
# r= 600

# %%
q, *w, r = (100, 200, 600)

print("q=", q)
print("w=", w, type(w))
print("r=", r)
# Out:
# q= 100
# w= [200] <class 'list'>
# r= 600

# %%
def functie(*args, a):
    print("args", args, type(args))

# %%
functie(231, 321, 31, a=23)
# Out:
# args (231, 321, 31) <class 'tuple'>

# %%
temperatura = input("Introduceți temperatura")
print ("Temperature în grade Fahrenheit este " + temperatura*1.8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[86], line 2
#       1 temperatura = input("Introduceți temperatura")
# ----> 2 print ("Temperature în grade Fahrenheit este " + temperatura*1.8)
#
# TypeError: can't multiply sequence by non-int of type 'float'

# %%
temperatura = int(input("Introduceți temperatura"))
print ("Temperature în grade Fahrenheit este " + temperatura*1.8)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[88], line 2
#       1 temperatura = int(input("Introduceți temperatura"))
# ----> 2 print ("Temperature în grade Fahrenheit este " + temperatura*1.8)
#
# TypeError: can only concatenate str (not "float") to str

# %%
temperatura = int(input("Introduceți temperatura"))
print ("Temperature în grade Fahrenheit este ", temperatura*1.8)
# Out:
# Temperature în grade Fahrenheit este  57.6

# %%
temperatura = int(input("Introduceți temperatura"))
print ("Temperature în grade Fahrenheit este ", temperatura*1.8)
# Out:
# Temperature în grade Fahrenheit este  577.8000000000001

# %%
temperatura = int(input("Introduceți temperatura"))
print ("Temperature în grade Fahrenheit este ", temperatura*1.8)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[94], line 1
# ----> 1 temperatura = int(input("Introduceți temperatura"))
#       2 print ("Temperature în grade Fahrenheit este ", temperatura*1.8)
#
# ValueError: invalid literal for int() with base 10: '21d'

# %%
a = 10
b = 0
print ( a/b ) if (b > 0 ) else print ( a )
# Out:
# 10

# %%
10 / 0
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[96], line 1
# ----> 1 10 / 0
#
# ZeroDivisionError: division by zero

# %%
x = 10 or 10 / 0
x
# Out:
# 10

# %%
x = True or 10 / 0
x
# Out:
# True

# %%
x = True or jdsajkdhjashdkjashkjdhaskjh 
x
# Out:
# True

# %%
x = False or jdsajkdhjashdkjashkjdhaskjh 
x
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[101], line 1
# ----> 1 x = False or jdsajkdhjashdkjashkjdhaskjh
#       2 x
#
# NameError: name 'jdsajkdhjashdkjashkjdhaskjh' is not defined

# %%
x = 10 / 0 or True
# Out:
# ---------------------------------------------------------------------------
# ZeroDivisionError                         Traceback (most recent call last)
# Cell In[104], line 1
# ----> 1 x = 10 / 0 or True
#
# ZeroDivisionError: division by zero

# %%
x = input("Introdu...") 
x
# Out:
# ''

# %%
x = "32131"
bool(x)
# Out:
# True

# %%
x = " "
bool(x)
# Out:
# True

# %%
x = ""
bool(x)
# Out:
# False

# %%
x = "text"

if x:
    print("Adevarat")
else:
    print("Fals")
# Out:
# Adevarat

# %%
x = ""

if x:
    print("Adevarat")
else:
    print("Fals")
# Out:
# Fals

# %%
x = ""

if bool(x):
    print("Adevarat")
else:
    print("Fals")
# Out:
# Fals

# %%
x = None

if x:
    print("Adevarat")
else:
    print("Fals")
# Out:
# Fals

# %%
x = None

if bool(x):
    print("Adevarat")
else:
    print("Fals")
# Out:
# Fals

# %%
bool(None)
# Out:
# False

# %%
x = 23

if x:
    print("Adevarat")
else:
    print("Fals")
# Out:
# Adevarat

# %%
x = -23

if x:
    print("Adevarat")
else:
    print("Fals")
# Out:
# Adevarat

# %%
x = 0

if x:
    print("Adevarat")
else:
    print("Fals")
# Out:
# Fals

# %%
x = input("Introdu...") or "333"
x
# Out:
# '333'

# %%
x = input("Introdu...") or "333"
x
# Out:
# '43423'

# %%
x = input("Introdu...") 
if not x:
    x = "333"
x
# Out:
# '333'

# %%
x = input("Introdu...") 
if not x:
    x = "333"
x
# Out:
# '321312ds'

# %%
print(0xA + 0xB + 0xC)
# Out:
# 33

# %%
i = 1
while i < 6:
    i += 1
    if i == 3 :
        break
else:
    i+=1
    print("i=", i)
    print("Acest else se executa la finalul buclei")
    
i += 1
print ("Value of i is : ", i)
# Out:
# Value of i is :  4

# %%
i = 1
while i < 6:
    i += 1
else:
    i+=1
    print("i=", i)
    print("Acest else se executa la finalul buclei")

i += 1
print ("Value of i is : ", i)
# Out:
# i= 7
# Acest else se executa la finalul buclei
# Value of i is :  8

# %%
for i in range(10):
    print("i=", i)
else:
    print("Am ajuns la finalul buclei")

print("Dupa bucla")
# Out:
# i= 0
# i= 1
# i= 2
# i= 3
# i= 4
# i= 5
# i= 6
# i= 7
# i= 8
# i= 9
# Am ajuns la finalul buclei
# Dupa bucla

# %%
for i in range(10):
    print("i=", i)
    if i % 7 == 0:
        break
else:
    print("Am ajuns la finalul buclei")

print("Dupa bucla")
# Out:
# i= 0
# Dupa bucla

# %%
lista = [10, 20, 30, 40, 50, 60]

for i in lista:
    if i % 7 == 0:
        este_divizibil = True
else:
    este_divizibil  = False

print("Exista numar divizibil cu 7??", este_divizibil)
# Out:
# Exista numar divizibil cu 7?? False

# %%
for i in range(-5, 4, 2):
    if(i<0):
        continue
    print(i, end= " ")
# Out:
# 1 3

# %%
list(range(0, 4, 2))
# Out:
# [0, 2]

# %%
list(range(0, 5, 2))
# Out:
# [0, 2, 4]

# %%
list(range(-5, 4, 2))
# Out:
# [-5, -3, -1, 1, 3]

# %%
total = 0 
for i in range(-10, 0, 2):
    if(i<-7):
        continue
    total += 1    
else:
    print("total:", total)
# Out:
# total: 3

# %%
total = 0 
for i in range(-10, 0, 2):
    if(i<-7):
        continue
    total += 1    
    if i == 0:
        break

else:
    print("total:", total)
# Out:
# total: 3

# %%
total = 0 
for i in range(-10, 0, 2):
    if(i<-7):
        continue
    total += 1    
    if i == -1:
        break

else:
    print("total:", total)
# Out:
# total: 3

# %%
list(range(-10, 0, 2))
# Out:
# [-10, -8, -6, -4, -2]

# %%
total = 0 
for i in range(-10, 0, 2):
    if(i<-7):
        continue
    total += 1    
    if i == -2:
        break

else:
    print("total:", total)

print("total dupa for:", total)
# Out:
# total dupa for: 3

# %%
def fun(x = 4, y = 5):
    y -= 1
    return x * y * 1
print(fun())
# Out:
# 16

# %%
nums = [1, 2, 3, 4, 5, 6, 7]
print(nums[::-5])
# Out:
# [7, 2]

# %%
text = "buna ziua"

text[::-1]
# Out:
# 'auiz anub'

# %%
text = "buna ziua"
reversed(text)

# %%
text = "buna ziua"
list(reversed(text))
# Out:
# ['a', 'u', 'i', 'z', ' ', 'a', 'n', 'u', 'b']

# %%
text = "buna ziua"
"".join(reversed(text))
# Out:
# 'auiz anub'

# %%
text = "buna ziua"
new_text = ""

for ch in text:
    new_text = ch + new_text 
    print("new_text:", new_text)

print(new_text)
# Out:
# new_text: b
# new_text: ub
# new_text: nub
# new_text: anub
# new_text:  anub
# new_text: z anub
# new_text: iz anub
# new_text: uiz anub
# new_text: auiz anub
# auiz anub

# %%
text = "buna ziua"


map(ord ,text)

# %%
ord("b")
# Out:
# 98

# %%
text = "buna ziua"
list(map(ord ,text))
# Out:
# [98, 117, 110, 97, 32, 122, 105, 117, 97]

# %%
def functie_map (x):
    return str(x) ## mapat/transformat

# %%
text = "buna ziua"
list(filter(ord ,text))

# %%
def functie_filter (x):
    return x > "m"  ## filtrez dupa conditie

# %%
text = "buna ziua"
list(filter(functie_filter ,text))
# Out:
# ['u', 'n', 'z', 'u']

# %%
text = "buna ziua"
list(filter(lambda x: x > "m" ,text))
# Out:
# ['u', 'n', 'z', 'u']

# %%
from functools import reduce

# %%
text = "buna ziua"


def functie_reduce(x, y):
    print("x=", x)
    print("y=", y)
    print( )
    return y + x ## reduce pe x si y la o noua valoare, care va devenit noul x si va fi apelata cu urmatorul y


reduce(functie_reduce, text)
# Out:
# x= b
# y= u
#
# x= ub
# y= n
#
# x= nub
# y= a
#
# x= anub
# y=
#
# x=  anub
# y= z
#
# x= z anub
# y= i
#
# x= iz anub
# y= u
#
# x= uiz anub
# y= a
# 'auiz anub'

# %%
text = "buna ziua"
reduce(lambda x, y: y+x, text)
# Out:
# 'auiz anub'

# %%
a = 0b1011
b = 0b1001
print(bin(a ^ b))
# Out:
# 0b10

# %%
a = 0b1011
a
# Out:
# 11

# %%
b
# Out:
# 9

# %%
a ^ b
# Out:
# 2

# %%
a = 10 
a << 1
print("bin(a)", bin(a))
print("bin(a << 1)", bin(a << 1), a << 1)
print("bin(a << 2)", bin(a << 2), a << 2)
# Out:
# bin(a) 0b1010
# bin(a << 1) 0b10100 20
# bin(a << 2) 0b101000 40

# %%
a = 10 
a >> 1
print("bin(a)", bin(a), a)
print("bin(a >> 1)", bin(a >> 1), a >> 1)
print("bin(a >> 2)", bin(a >> 2), a >> 2)
# Out:
# bin(a) 0b1010 10
# bin(a >> 1) 0b101 5
# bin(a >> 2) 0b10 2

# %%
a = 0x10 
a | a
# Out:
# 16

# %%
a = 0x1100
b = 0x1010

bin(a ^ b)
# Out:
# '0b100010000'

# %%
a & a
# Out:
# 16

# %%
val = ['Python', 'Tuple']
val_t = tuple(val)
val_t.pop()
print(val_t)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[187], line 3
#       1 val = ['Python', 'Tuple']
#       2 val_t = tuple(val)
# ----> 3 val_t.pop()
#       4 print(val_t)
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
val = ['Python', 'Tuple']
val_t = val
val_t.pop()
print(val_t)
# Out:
# ['Python']

# %%
val = ['Python', 'Tuple']
val_t = val
val_t.pop(0)
print(val_t)
# Out:
# ['Tuple']

# %%
greeting = "Good Morning"
for ch in greeting:
    if ch == 'o':
        break
    print(ch)
else:
    print("Good Night")
# Out:
# G

# %%
greeting = "Good Morning"
for ch in greeting:
    if ch == 'o':
        continue
    print(ch, end=" ")
else:
    print("Good Night")
# Out:
# G d   M r n i n g Good Night

# %%
tupl = tuple('Python World!')
print(tupl[:-7])
# Out:
# ('P', 'y', 't', 'h', 'o', 'n')

# %%
tupl = 'Python World!'
print(tupl[:-7])
# Out:
# Python

# %%
x = 100
def glob():
    global x
    x = 20
glob()
print(x)
# Out:
# 20

# %%
a = input()
b = int(input())
print(a*b)
# Out:
# 222

# %%
myList = [5, 10, 28, 32, 97, 103]
print(32 in myList)
# Out:
# True

# %%
x = "32131ASFF"
x.isalnum()
# Out:
# True

# %%
x = "32131ASFF"
x.isalpha()
# Out:
# False

# %%
x = "dsaASFF"
x.isalpha()
# Out:
# True

# %%
x = "dsaASFF##@!"
x.isalpha()
# Out:
# False

# %%
x = "dsaASF F"
x.isalpha()
# Out:
# False

# %% [markdown]
# # find vs index

# %%
"salut".find("m")
# Out:
# -1

# %%
"salut".find("a")
# Out:
# 1

# %%
"salut salut".find("a")
# Out:
# 1

# %%
"salut salut".index("a")
# Out:
# 1

# %%
"salut salut".index("m")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[206], line 1
# ----> 1 "salut salut".index("m")
#
# ValueError: substring not found

# %%
"333".zfill(10)
# Out:
# '0000000333'

# %%
"333".zfill(3)
# Out:
# '333'

# %% [markdown]
# # Functia zfill -> pune zero-uri in fata stringului

# %%
print("333".zfill(10))
print("12341231".zfill(10))
print("31231".zfill(10))
# Out:
# 0000000333
# 0012341231
# 0000031231
