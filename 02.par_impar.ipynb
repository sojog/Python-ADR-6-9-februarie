# %%
nr = int(input("Introdu nr"))

"im" * (nr % 2) + "par"
# Out:
# 'par'

# %%
o_lista = ["1", "2", "3"]
noua_lista = [ int(i) ** 2  for i in o_lista]
noua_lista
# Out:
# [1, 4, 9]

# %%
o_lista = ["1", "2", "3"]
list(map(lambda x: int(x)**2, o_lista))
# Out:
# [1, 4, 9]
