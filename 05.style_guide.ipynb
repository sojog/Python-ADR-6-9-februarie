# %%
if 2 > 1:
 print("Adevarat")
# Out:
# Adevarat

# %%
if 2 > 1:print("Adevarat")
# Out:
# Adevarat

# %%
if 2 > 1:{
print("Adevarat")}
# Out:
# Adevarat

# %%
if 2 > 1:
                    print("Adevarat")
# Out:
# Adevarat

# %%
for i in range(80):
    print(f"{i}"[-1], end="", sep="")
# Out:
# 01234567890123456789012345678901234567890123456789012345678901234567890123456789

# %%
with open('/path/to/some/file/you/want/to/read') as file_1, \
    open('/path/to/some/file/being/written', 'w') as file_2:
    file_2.write(file_1.read())

# %%
VALOARE_TVA = 21

# %%
VALOARE_TVA = 25

# %%
# VALOARE_TVA -> constante
# valoare_tva -> variabile (snake_case)
# ValoareTVA -> clase (CamelCase)
