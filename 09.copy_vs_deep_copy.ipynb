# %%
x = 10
y = x

# %%
y = 20

# %%
print("x=", x)
# Out:
# x= 10

# %% [markdown]
# # Shallow Copy

# %%
x = [10, 20, 30]
y = x

# %%
y.append(40)

# %%
y
# Out:
# [10, 20, 30, 40]

# %%
x
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# # Deep Copy

# %%
x = [10, 20, 30]
y = x[::]

# %%
x
# Out:
# [10, 20, 30]

# %%
y.append(40)

# %%
y
# Out:
# [10, 20, 30, 40]

# %%
x
# Out:
# [10, 20, 30]

# %% [markdown]
# # Deep copy -> folosind functie

# %%
import copy

# %%
x = [10, 20, 30]
y = copy.deepcopy(x)

# %%
y
# Out:
# [10, 20, 30]

# %%
y.append(23103)

# %%
y
# Out:
# [10, 20, 30, 23103]

# %%
x
# Out:
# [10, 20, 30]
