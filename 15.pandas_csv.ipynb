# %%
import pandas as pd

# %%
df = pd.read_csv("organizations-100.csv")
df
# Out:
#     Index  Organization Id                     Name  \
# 0       1  FAB0d41d5b5d22c              Ferrell LLC
# 1       2  6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 2       3  0bFED1ADAE4bcC1               Hester Ltd
# 3       4  2bFC1Be8a4ce42f           Holder-Sellers
# 4       5  9eE8A6a4Eb96C24              Mayer Group
# ..    ...              ...                      ...
# 95     96  0a0bfFbBbB8eC7c             Holmes Group
# 96     97  BA6Cd9Dae2Efd62                 Good Ltd
# 97     98  E7df80C60Abd7f9        Clements-Espinoza
# 98     99  AFc285dbE2fEd24               Mendez Inc
# 99    100  e9eB5A60Cef8354           Watkins-Kaiser
#
#                            Website                      Country  \
# 0               https://price.net/             Papua New Guinea
# 1   http://www.hall-buchanan.info/                      Finland
# 2        http://sullivan-reed.com/                        China
# 3              https://becker.com/                 Turkmenistan
# ...

# %%
df = pd.read_csv("organizations-100.csv", index_col="Index")
df
# Out:
#        Organization Id                     Name  \
# Index
# 1      FAB0d41d5b5d22c              Ferrell LLC
# 2      6A7EdDEA9FaDC52  Mckinney, Riley and Day
# 3      0bFED1ADAE4bcC1               Hester Ltd
# 4      2bFC1Be8a4ce42f           Holder-Sellers
# 5      9eE8A6a4Eb96C24              Mayer Group
# ...                ...                      ...
# 96     0a0bfFbBbB8eC7c             Holmes Group
# 97     BA6Cd9Dae2Efd62                 Good Ltd
# 98     E7df80C60Abd7f9        Clements-Espinoza
# 99     AFc285dbE2fEd24               Mendez Inc
# 100    e9eB5A60Cef8354           Watkins-Kaiser
#
#                               Website                      Country  \
# Index
# 1                  https://price.net/             Papua New Guinea
# 2      http://www.hall-buchanan.info/                      Finland
# 3           http://sullivan-reed.com/                        China
# 4                 https://becker.com/                 Turkmenistan
# ...

# %%
df.keys()
# Out:
# Index(['Organization Id', 'Name', 'Website', 'Country', 'Description',
#        'Founded', 'Industry', 'Number of employees'],
#       dtype='object')

# %%
df.describe()
# Out:
#            Founded  Number of employees
# count   100.000000           100.000000
# mean   1995.410000          4964.860000
# std      15.744228          2850.859799
# min    1970.000000           236.000000
# 25%    1983.500000          2741.250000
# 50%    1995.000000          4941.500000
# 75%    2010.250000          7558.000000
# max    2021.000000          9995.000000

# %%
df.dtypes
# Out:
# Organization Id        object
# Name                   object
# Website                object
# Country                object
# Description            object
# Founded                 int64
# Industry               object
# Number of employees     int64
# dtype: object

# %%
df.Country.unique()
# Out:
# array(['Papua New Guinea', 'Finland', 'China', 'Turkmenistan',
#        'Mauritius', 'Bahamas', 'Pakistan',
#        'Heard Island and McDonald Islands', 'Kuwait', 'Uzbekistan',
#        'Bouvet Island (Bouvetoya)', 'Denmark', 'Liberia',
#        'United Arab Emirates', 'Sweden', 'Honduras', 'Uganda',
#        'Hong Kong', 'Botswana', 'Korea', 'Luxembourg', 'Guadeloupe',
#        'Monaco', 'Belgium', 'South Africa', 'Romania', 'Czech Republic',
#        'Christmas Island', 'Philippines', 'Australia', 'Chad', 'Zimbabwe',
#        'Nepal', 'Taiwan', 'Kyrgyz Republic', 'Bolivia', 'Kenya',
#        'Guatemala', 'Belarus', 'Jersey', 'Grenada', 'Cape Verde',
#        'Trinidad and Tobago', 'Benin', 'Western Sahara',
#        'Northern Mariana Islands', 'Germany', 'Canada', 'Tonga',
#        'French Southern Territories', "Cote d'Ivoire", 'Mayotte',
#        'Cayman Islands', 'Nigeria', 'Marshall Islands', 'Palau', 'Turkey',
# ...

# %%
df.Country.nunique()
# Out:
# 84

# %%
df.Industry.unique()
# Out:
# array(['Plastics', 'Glass / Ceramics / Concrete', 'Public Safety',
#        'Automotive', 'Transportation', 'Primary / Secondary Education',
#        'Publishing Industry', 'Import / Export',
#        'Outsourcing / Offshoring', 'Food / Beverages',
#        'Museums / Institutions', 'Medical Practice', 'Maritime',
#        'Facilities Services',
#        'Investment Management / Hedge Fund / Private Equity',
#        'Architecture / Planning', 'Wholesale', 'Construction',
#        'Luxury Goods / Jewelry', 'Pharmaceuticals', 'Insurance',
#        'Real Estate / Mortgage', 'Banking / Mortgage', 'Legal Services',
#        'Logistics / Procurement', 'Civil Engineering',
#        'Mechanical or Industrial Engineering', 'Hospitality',
#        'Venture Capital / VC', 'Utilities', 'Human Resources / HR',
#        'Legislative Office', 'Music',
#        'Electrical / Electronic Manufacturing',
#        'Non - Profit / Volunteering', 'Writing / Editing',
# ...

# %%
df['Industry'].unique()
# Out:
# array(['Plastics', 'Glass / Ceramics / Concrete', 'Public Safety',
#        'Automotive', 'Transportation', 'Primary / Secondary Education',
#        'Publishing Industry', 'Import / Export',
#        'Outsourcing / Offshoring', 'Food / Beverages',
#        'Museums / Institutions', 'Medical Practice', 'Maritime',
#        'Facilities Services',
#        'Investment Management / Hedge Fund / Private Equity',
#        'Architecture / Planning', 'Wholesale', 'Construction',
#        'Luxury Goods / Jewelry', 'Pharmaceuticals', 'Insurance',
#        'Real Estate / Mortgage', 'Banking / Mortgage', 'Legal Services',
#        'Logistics / Procurement', 'Civil Engineering',
#        'Mechanical or Industrial Engineering', 'Hospitality',
#        'Venture Capital / VC', 'Utilities', 'Human Resources / HR',
#        'Legislative Office', 'Music',
#        'Electrical / Electronic Manufacturing',
#        'Non - Profit / Volunteering', 'Writing / Editing',
# ...

# %%
df[ ['Name', 'Website' ] ]
# Out:
#                           Name                         Website
# Index
# 1                  Ferrell LLC              https://price.net/
# 2      Mckinney, Riley and Day  http://www.hall-buchanan.info/
# 3                   Hester Ltd       http://sullivan-reed.com/
# 4               Holder-Sellers             https://becker.com/
# 5                  Mayer Group          http://www.brewer.com/
# ...                        ...                             ...
# 96                Holmes Group           https://mcdowell.org/
# 97                    Good Ltd               http://duffy.com/
# 98           Clements-Espinoza         http://www.flowers.net/
# 99                  Mendez Inc          https://www.burke.net/
# 100             Watkins-Kaiser         http://www.herring.com/
#
# [100 rows x 2 columns]

# %%
df['Number of employees'].describe(),
# Out:
# (count     100.000000
#  mean     4964.860000
#  std      2850.859799
#  min       236.000000
#  25%      2741.250000
#  50%      4941.500000
#  75%      7558.000000
#  max      9995.000000
#  Name: Number of employees, dtype: float64,)

# %%
df[df['Number of employees'] > 5000]['Number of employees'].nunique()
# Out:
# 48

# %%
df.plot.bar(x="Name", y='Number of employees')
# Out:
# <Axes: xlabel='Name'>

# %%
df[df["Number of employees"] < 400].plot.bar(x="Name", y='Number of employees')
# Out:
# <Axes: xlabel='Name'>

# %%
df[df["Number of employees"] < 400].plot.pie(y='Number of employees', labels=df[df["Number of employees"] < 400]["Name"])
# Out:
# <Axes: ylabel='Number of employees'>

# %%
df.plot.pie(y='Number of employees')
# Out:
# <Axes: ylabel='Number of employees'>

# %% [markdown]
# # pip install pygwalker

# %%
import pygwalker as pyg

# %%
walker = pyg.walk(df)
walker
# Out:
# Box(children=(HTML(value='\n<div id="ifr-pyg-00064a61b0dbf3995YfN1bOIKlChZV39" style="height: auto">\n    <hea…
# <script>
#     window.addEventListener("message", function(event) {
#         const backgroundMap = {
#             "dark": "hsl(240 10% 3.9%)",
#             "light": "hsl(0 0 100%)",
#         };
#         const colorMap = {
#             "dark": "hsl(0 0% 98%)",
#             "light": "hsl(240 10% 3.9%)",
#         };
#         if (event.data.action === "changeAppearance" && event.data.gid === "00064a61b0dbf3995YfN1bOIKlChZV39") {
#             var iframe = document.getElementById("gwalker-00064a61b0dbf3995YfN1bOIKlChZV39");
#             iframe.style.background  = backgroundMap[event.data.appearance];
#             iframe.style.color = colorMap[event.data.appearance];
#         }
#     });
# </script>
